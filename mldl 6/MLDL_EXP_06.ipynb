# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

features = ['HP','Attack','Defense']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model = KMeans(n_clusters=3,random_state=42)

df['Cluster'] = model.fit_predict(X_scaled)

sns.scatterplot(x=X['HP'],y=X['Attack'],hue=df['Cluster'],palette='viridis')
plt.xlabel("HP")
plt.ylabel("Attack")
plt.title("K-Means Clustering")
plt.show()
# Out:
#      <input type="file" id="files-29513288-823d-4003-90a2-63dcdc50c8c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-29513288-823d-4003-90a2-63dcdc50c8c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

features = ['HP','Attack','Defense']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss,marker='o')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

optimal_k = 3

model = KMeans(n_clusters=optimal_k,random_state=42)

df['Cluster'] = model.fit_predict(X_scaled)

sns.scatterplot(x=X['HP'],y=X['Attack'],hue=df['Cluster'],palette='viridis')
plt.xlabel("HP")
plt.ylabel("Attack")
plt.title("K-Means Clustering (Tuned)")
plt.show()
# Out:
#      <input type="file" id="files-ad728e4a-7425-4781-be14-f94cb57e65d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad728e4a-7425-4781-be14-f94cb57e65d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

features = ['HP','Attack','Defense']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model = AgglomerativeClustering(n_clusters=3)

df['Cluster'] = model.fit_predict(X_scaled)

sns.scatterplot(x=X['HP'],y=X['Attack'],hue=df['Cluster'],palette='viridis')
plt.xlabel("HP")
plt.ylabel("Attack")
plt.title("Hierarchical Clustering")
plt.show()
# Out:
#      <input type="file" id="files-2f3bffd5-b54d-4163-8553-1a9f9701db3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f3bffd5-b54d-4163-8553-1a9f9701db3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram,linkage

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

features = ['HP','Attack','Defense']
X = df[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

plt.figure(figsize=(10,6))
dendrogram(linkage(X_scaled,method='ward'))
plt.title("Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()

model = AgglomerativeClustering(n_clusters=3)

df['Cluster'] = model.fit_predict(X_scaled)

sns.scatterplot(x=X['HP'],y=X['Attack'],hue=df['Cluster'],palette='viridis')
plt.xlabel("HP")
plt.ylabel("Attack")
plt.title("Hierarchical Clustering (Tuned)")
plt.show()
# Out:
#      <input type="file" id="files-7f478769-5093-49c4-8931-67ee233c3b1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f478769-5093-49c4-8931-67ee233c3b1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
